# %% [markdown]
# <a href="https://colab.research.google.com/github/RifleB-1311/Baitap-numpy/blob/main/Numpy05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài tập 1: Bạn hãy tìm hiểu:
# 1. Thư viện Pillow (viết tắt PIL) chuyên dụng thao tác với ảnh;
# 2. Sử dụng thư viện PIL để đọc 1 bức ảnh vào bộ nhớ
# 3. In bức ảnh ra màn hình
# 4. Chuyển bức ảnh từ cấu trúc dữ liệu của PIL sang NumPy array và xuất ra số chiều (ndim)
# và kích thước (shape) của array kết quả.
# 5. In nội dung của array thu được ở câu (4) ra màn hình.
# 6. Bạn hãy thử tìm hiểu các thao tác khác với ảnh như: (i) chuyển ảnh màu sang ảnh xám; (ii)
# lưu ảnh vào máy; (iii) phòng to hay thu nhỏ ảnh; .v.v.
# 7. Bạn hãy tìm hiểu thư viện OpenCV chuyên dụng xử lý ảnh.

# %%
import numpy as np
import PIL
from google.colab import files
from IPython.display import Image
from PIL import Image
import glob, os
uploaded = files.upload()
# Out:
#      <input type="file" id="files-42de37e5-199f-4307-ad9e-3615b92953ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42de37e5-199f-4307-ad9e-3615b92953ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 9fe096e00b0125ff1143f2e4e8539e42.jpg to 9fe096e00b0125ff1143f2e4e8539e42 (2).jpg

# %%
a = PIL.Image.open("9fe096e00b0125ff1143f2e4e8539e42 (2).jpg")
a
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x599 at 0x7F944013D950>

# %%
e = np.asarray(PIL.Image.open("9fe096e00b0125ff1143f2e4e8539e42 (2).jpg"))
print(e)
# Out:
# [[[14 25 43]
#   [14 25 43]
#   [14 25 43]
#   ...
#   [27 44 70]
#   [27 44 70]
#   [27 44 70]]
#
#  [[15 26 44]
#   [15 26 44]
#   [15 26 44]
#   ...
#   [29 46 72]
#   [29 46 72]
#   [29 46 72]]
#
#  [[15 26 44]
#   [15 26 44]
#   [15 26 44]
#   ...
#   [31 48 74]
#   [31 48 74]
#   [31 48 74]]
#
#  ...
#
#  [[ 8 14 14]
#   [ 5 11 11]
#   [ 3  8 11]
#   ...
#   [24 25 20]
#   [20 21 16]
#   [16 17 12]]
#
#  [[ 5 11 11]
#   [ 0  6  6]
#   [ 0  5  8]
#   ...
#   [20 19 15]
#   [19 18 14]
#   [15 14 10]]
#
#  [[18 24 24]
#   [13 19 19]
#   [19 24 27]
#   ...
#   [19 15 12]
#   [21 17 14]
#   [16 12  9]]]

# %%
c = e.ndim
d = e.shape
print(c)
print(d)
# Out:
# 3
# (599, 900, 3)

# %% [markdown]
# Bài tập 2 - Thư viện thao tác với cấu trúc Tensor: Thực ra thư viện NumPy là thư viện nền tảng,
# dựa trên nó có nhiều thư viện được phát triển chuyên biệt. Để thao tác với cấu trúc Tensor có 2
# thư viện rất nổi tiếng, gồm:
# - TensorFlow
# - PyTorch
# Bạn hãy:
# 1. Lựa chọn 1 trong 2 thư viện kể trên
# 2. Thực hiện tạo các Tensor hạng 1, 2, 3, 4 bằng cách sử dụng thư viện đó

# %%
# !pip3 install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.10.0.2)

# %%
import torch
a = torch.Tensor(np.array([1, 7]))  #Tensor hạng 1
print(a)
print(a.ndim)
# Out:
# tensor([1., 7.])
# 1

# %%
b = torch.Tensor(np.array([[1, 4],[2,3]]))    #Tensor hạng 2
print(b)
print(b.ndim)
# Out:
# tensor([[1., 4.],
#         [2., 3.]])
# 2

# %%
c = torch.Tensor(np.random.randint(0, 1000, size = 280)).reshape(5, 7, 8)   #Tensor hạng 3
print(c)
print(c.ndim)
# Out:
# tensor([[[ 53., 456., 934., 887., 894., 901., 420., 555.],
#          [468., 263., 128., 636., 713.,  70., 415.,  35.],
#          [467., 562., 656., 170., 440., 537.,   8., 268.],
#          [989., 737., 656., 990.,  55.,  13., 728., 929.],
#          [277., 121., 625., 643., 627.,  32., 958.,  77.],
#          [715., 589., 293., 615., 460., 270., 302., 485.],
#          [792., 272., 954., 658., 432., 376.,  70., 760.]],
#
#         [[936., 915., 777.,  34., 593., 582., 420., 928.],
#          [152., 966., 773., 761., 894., 627., 733.,  24.],
#          [441., 807., 588.,  81., 467., 884., 354., 129.],
#          [217., 550., 322., 386.,  36., 396., 263., 419.],
#          [345., 484., 340., 137., 860., 585., 844., 651.],
#          [666., 180., 377., 469.,  76., 682., 241.,  52.],
#          [636., 777., 725., 965., 873., 966., 848., 218.]],
#
#         [[ 58., 213., 852., 335., 269., 695., 717., 408.],
#          [537., 882., 839.,  98., 187., 433., 586., 818.],
#          [569., 787., 119., 557.,   4.,  40., 807., 223.],
#          [643., 197., 105., 133., 181.,  94., 178., 851.],
#          [  0., 974., 945., 673., 703., 723., 349., 809.],
#          [649., 609., 301., 749., 430., 940.,  33., 642.],
#          [456., 356., 578.,  85.,  29., 122., 801., 226.]],
#
#         [[809., 402.,  84., 246., 132., 155., 700., 338.],
#          [352., 932., 390., 258., 785., 669., 959., 475.],
#          [778., 683., 847., 213., 940., 850., 477., 859.],
#          [922., 671., 118., 394., 895., 758., 770., 449.],
#          [ 85., 566., 859., 401., 259., 288., 526., 577.],
#          [456., 696., 846., 937., 654., 591., 651., 866.],
#          [660.,  12., 941., 669., 435., 437., 131., 111.]],
#
#         [[413., 629., 778., 702., 806., 454., 760., 747.],
#          [ 21., 245., 914., 418., 281., 818., 158., 292.],
#          [180., 682., 298., 560., 128., 410., 809., 401.],
#          [744.,  49., 515.,  53., 540., 797., 266.,  53.],
#          [ 43., 948., 678., 207., 198., 967., 665., 888.],
#          [654., 675., 542., 571., 302., 111., 705., 918.],
#          [595., 876., 150., 909., 165., 836.,  33., 708.]]])
# 3

# %%
d = torch.Tensor(np.random.randint(0, 1000, size = 1120)).reshape(5, 7, 8, 4)   #Tensor hạng 4
print(d)
print(d.ndim)
# Out:
# tensor([[[[440., 976., 249., 353.],
#           [705., 608., 541., 190.],
#           [823., 102., 509., 734.],
#           ...,
#           [535., 119., 375., 575.],
#           [876., 300., 353., 296.],
#           [246.,  95., 789., 691.]],
#
#          [[929., 427., 978., 930.],
#           [413., 663., 531., 322.],
#           [658.,  46., 756., 860.],
#           ...,
#           [970., 434., 695., 667.],
#           [172., 590., 688., 198.],
#           [710., 106., 279., 163.]],
#
#          [[236., 854., 718., 240.],
#           [368., 564., 481., 212.],
#           [217., 933., 524., 701.],
#           ...,
#           [ 31., 381., 925., 838.],
#           [833., 384., 646., 907.],
#           [948., 255., 395., 684.]],
#
#          ...,
#
#          [[380., 626.,  22.,  14.],
#           [297., 931., 390., 902.],
#           [659., 938., 796., 122.],
#           ...,
#           [  9., 782., 474., 372.],
#           [ 70., 814.,  15.,  97.],
#           [962., 304., 644., 501.]],
#
#          [[118., 494., 375., 579.],
#           [220., 717., 765.,  26.],
#           [587., 528., 982., 702.],
#           ...,
#           [409.,  26., 186.,  41.],
#           [114., 648., 368., 838.],
#           [839., 149., 405., 316.]],
#
#          [[457., 725., 912., 155.],
#           [668., 120., 979., 821.],
#           [281., 880., 337., 555.],
#           ...,
#           [924.,   9., 259., 301.],
#           [548., 689., 105., 309.],
#           [305., 148., 750., 337.]]],
#
#
#         [[[ 41., 812., 195., 120.],
#           [511.,  60., 179., 471.],
#           [  8., 424., 696., 997.],
#           ...,
#           [175., 813., 311., 608.],
#           [641., 298., 500., 409.],
#           [383., 687., 347., 173.]],
#
#          [[911., 350., 303., 577.],
#           [504., 104., 740., 206.],
#           [712., 809., 236., 411.],
#           ...,
#           [801., 161., 640., 648.],
#           [873., 673., 575.,  26.],
#           [452.,  76., 490., 440.]],
#
#          [[ 83., 697., 363., 341.],
#           [674., 993., 411., 869.],
#           [463., 601., 447., 184.],
#           ...,
#           [ 99., 348., 518., 472.],
#           [399., 964., 247., 162.],
#           [575., 896., 878., 835.]],
#
#          ...,
#
#          [[831., 132., 427., 115.],
#           [ 88., 598., 475., 230.],
#           [ 77., 361., 945., 756.],
#           ...,
#           [653., 586., 180., 671.],
#           [252., 234., 461., 985.],
#           [990., 453.,  50., 488.]],
#
#          [[707., 417., 533., 563.],
#           [723., 984., 785., 105.],
#           [336., 117., 900., 643.],
#           ...,
#           [635., 819.,  76., 544.],
#           [160., 170., 453., 360.],
#           [ 37., 560., 132.,  17.]],
#
#          [[255., 328., 130.,  43.],
#           [390.,  49., 950., 563.],
#           [392., 281., 775., 597.],
#           ...,
#           [718., 331., 563., 291.],
#           [776., 701., 202., 352.],
#           [321.,   9., 945.,  81.]]],
#
#
#         [[[ 49., 865., 851., 412.],
#           [496., 536., 384., 653.],
#           [728., 251., 711., 343.],
#           ...,
#           [844., 213.,  73., 306.],
#           [728., 547., 906., 958.],
#           [809.,  43., 310.,  46.]],
#
#          [[793., 112., 221., 503.],
#           [997., 637., 772., 635.],
#           [675., 570., 547., 851.],
#           ...,
#           [340., 792., 367., 866.],
#           [719., 233., 854., 239.],
#           [ 78., 423., 534., 350.]],
#
#          [[ 43., 581., 451., 995.],
#           [617., 123., 936., 634.],
#           [527., 793.,  49., 632.],
#           ...,
#           [852., 995., 243., 534.],
#           [ 39.,  68., 369., 280.],
#           [947., 729., 959., 219.]],
#
#          ...,
#
#          [[975., 994., 674., 283.],
#           [188., 665., 800., 514.],
#           [997., 617., 512., 604.],
#           ...,
#           [180.,  62., 317., 872.],
#           [700., 754., 160., 588.],
#           [380., 582.,  17.,  13.]],
#
#          [[267., 628.,  51., 532.],
#           [702.,  73., 696., 313.],
#           [103., 745., 684., 581.],
#           ...,
#           [879., 946.,  91., 993.],
#           [594., 372., 498., 768.],
#           [170., 888., 427., 379.]],
#
#          [[338., 651., 907., 651.],
#           [137.,  37., 847., 941.],
#           [ 68., 593.,  83., 875.],
#           ...,
#           [731., 236., 362., 597.],
#           [370.,  47., 421., 107.],
#           [495., 806., 261., 516.]]],
#
#
#         [[[465., 956., 661., 321.],
#           [219., 126., 853., 577.],
#           [935., 751., 188., 272.],
#           ...,
#           [331., 376., 390., 708.],
#           [943., 468.,  85., 330.],
#           [603., 803., 899., 519.]],
#
#          [[968., 916., 653., 812.],
#           [143., 823., 817., 967.],
#           [645., 695., 245., 159.],
#           ...,
#           [465., 945., 371., 707.],
#           [ 17., 138., 441., 845.],
#           [672., 547., 589., 264.]],
#
#          [[695., 115.,  85., 178.],
#           [  9., 957., 757.,  45.],
#           [612., 225., 736., 669.],
#           ...,
#           [727., 461.,  65., 974.],
#           [184., 798., 284., 497.],
#           [323.,  60., 667., 728.]],
#
#          ...,
#
#          [[ 59., 378., 726., 532.],
#           [883., 372.,  56., 115.],
#           [281., 409., 279., 368.],
#           ...,
#           [291., 569., 359., 344.],
#           [680., 122., 295., 807.],
#           [307., 560., 960., 746.]],
#
#          [[326., 741., 233., 515.],
#           [796., 794., 987., 596.],
#           [105.,  81., 903., 622.],
#           ...,
#           [359., 871.,  78.,  36.],
#           [970., 761., 444., 700.],
#           [519., 555., 136., 477.]],
#
#          [[987., 816., 678., 774.],
#           [861., 454., 227., 322.],
#           [625., 570., 950., 282.],
#           ...,
#           [ 39., 871., 594., 355.],
#           [893., 922., 161., 737.],
#           [125., 807., 222., 651.]]],
#
#
#         [[[984., 402., 229., 564.],
#           [954., 482., 929., 860.],
#           [502., 684., 291., 816.],
#           ...,
#           [954., 198., 806., 818.],
#           [501., 664., 373., 547.],
#           [874., 237., 957.,  46.]],
#
#          [[709., 817., 455., 894.],
#           [889., 451., 935.,   0.],
#           [885., 444., 444., 115.],
#           ...,
#           [271., 550., 812.,  51.],
#           [996., 972., 598., 613.],
#           [123.,  75., 333., 108.]],
#
#          [[442., 182., 520., 713.],
#           [181., 681.,  27., 449.],
#           [453., 452., 622., 129.],
#           ...,
#           [322., 583., 514., 456.],
#           [268., 323., 281., 388.],
#           [200., 567., 769., 188.]],
#
#          ...,
#
#          [[149.,  58., 375., 270.],
#           [247., 188., 578.,  62.],
#           [691., 735.,  67., 308.],
#           ...,
#           [634.,  76., 127., 531.],
#           [919., 142.,  51., 341.],
#           [844., 734., 227., 495.]],
#
#          [[391., 297., 227., 137.],
#           [748., 112., 971.,  87.],
#           [402., 302., 130., 425.],
#           ...,
#           [183., 428., 201., 910.],
#           [288., 396., 340., 435.],
#           [359., 168.,  70.,  60.]],
#
#          [[103.,  68., 416., 620.],
#           [ 36., 332., 187., 600.],
#           [417., 701., 941., 354.],
#           ...,
#           [541., 652.,  95., 887.],
#           [927.,  30.,  83., 425.],
#           [976., 582., 817., 834.]]]])
# 4
